# %%
import json
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
with open('MALE_PRONOUN_DICT.json', 'r') as file:
    male_pronouns = json.load(file)
with open('FEMALE_PRONOUN_DICT.json', 'r') as file:
    female_pronouns = json.load(file)

# %%
male_df = pd.DataFrame(male_pronouns)
female_df = pd.DataFrame(female_pronouns)

# %%
female_df
# Out:
#                  0                               1
# 0              she                      [they, he]
# 1              her                    [their, his]
# 2             hers                   [theirs, his]
# 3          herself             [themself, himself]
# 4            woman                   [person, man]
# 5            women                   [people, men]
# 6           mother                [parent, father]
# 7          mothers              [parents, fathers]
# 8             mama                    [mapa, papa]
# 9            mommy                   [mapa, daddy]
# 10           mamma                   [mapa, poppa]
# 11          sister              [sibling, brother]
# 12         sisters            [siblings, brothers]
# 13             sis                      [sib, bro]
# 14             mrs                        [mx, mr]
# 15            miss                        [mx, mr]
# 16        mistress                    [mx, mister]
# ...
